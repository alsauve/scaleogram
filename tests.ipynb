# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import scaleogram as scg
import seaborn as sns
plt.rcParams['figure.figsize'] = [14,6]
plt.rcParams['font.size'] = 14.0
scg.test_cws()
# Out:
# Multi-purpose test demo (needs graphic output for matplotlib)
#   Plot Mexican Hat wavelet in time and frequency domains
#   Plot scaleogram of a gaussian
#   Plot test grid
